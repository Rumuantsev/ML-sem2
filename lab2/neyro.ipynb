# %% [markdown]
# ## 2. Решение задач
#
# ### Функция 1
# \[
# f(x) = 3x^2 - 12x + 4
# \]
#
# Берём производную:
# \[
# f'(x) = 6x - 12
# \]
#
# Приравняем к нулю:
# \[
# 6x - 12 = 0 \;\;\Rightarrow\;\; x = 2
# \]
#
# Вторая производная:
# \[
# f''(x) = 6 > 0
# \]
#
# Так как вторая производная положительна, в точке \(x = 2\) функция имеет **минимум**.
#
# 👉 **Точка минимума: \(x = 2\)**
#
# ---
#
# ### Функция 2
# \[
# f(x) = x(x^2 - 9) = x^3 - 9x
# \]
#
# Берём производную:
# \[
# f'(x) = 3x^2 - 9
# \]
#
# Приравняем к нулю:
# \[
# 3x^2 - 9 = 0 \;\;\Rightarrow\;\; x^2 = 3 \;\;\Rightarrow\;\; x = \pm \sqrt{3}
# \]
#
# Вторая производная:
# \[
# f''(x) = 6x
# \]
#
# - При \(x = -\sqrt{3}\):
# \[
# f''(-\sqrt{3}) = -6\sqrt{3} < 0
# \]
# Это **максимум**.
#
# - При \(x = \sqrt{3}\):
# \[
# f''(\sqrt{3}) = 6\sqrt{3} > 0
# \]
# Это **минимум**.
#
# 👉 **Точка минимума: \(x = \sqrt{3}\)**

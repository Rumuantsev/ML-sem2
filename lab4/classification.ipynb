# %% [markdown]
# ![image.png](1.jpg)
#
# ![image.png](2.jpg)
#
# ##### 1
# $
# L = - (ln(0.5) + ln(0.5)) = 2\ln(2) \approx 1.38
# $
# ##### 2
# $
# -(\ln(0.6) + \ln(x)) = 2\ln(2)
# $
#
# $
# -\ln(0.6) - \ln(x) = \ln(4)
# $
#
# $
# \ln(4) + \ln(0.6) = \ln(4 \times 0.6) = \ln(2.4)
# $
#
# $
# -\ln(x) = \ln(2.4)
# $
#
# $
# \ln(x) = \ln\left(\frac{1}{2.4}\right)
# $
#
# $
# x = \frac{1}{2.4} = \frac{5}{12} \approx 0.41
# $
#
# ##### 3
# $
# -(\ln(0.6) + \ln(x)) = \frac{2\ln(2)}{1.5}
# $
#
# $
# \frac{2\ln(2)}{1.5} = \frac{4}{3}\ln(2) = \ln(2^{4/3})
# $
#
# $
# -(\ln(0.6) + \ln(x)) = -\ln(0.6) - \ln(x)
# $
#
# $
# -\ln(x) = \ln(2^{4/3}) + \ln(0.6)
# $
#
# $
# \ln(2^{4/3}) + \ln(0.6) = \ln(2^{4/3} \times 0.6) = \ln\left(2^{4/3} \times \frac{3}{5}\right)
# $
#
# $
# x = \frac{5}{3 \times 2^{4/3}} = \frac{5}{6 \times \sqrt[3]{2}}
# $
#
# $
# x = \frac{5}{6\sqrt[3]{2}} \approx 0.66
# $

# %% [markdown]
# ##### 4
# Рассмотрим два дурацких классификатора К1 и К2.
#
# Дурацкий классификатор К1 был натренирован по тренировочной выборке, содержащей 5
# объектов класса 0 и 5 объектов класса 1.
#
# Дурацкий классификатор К2 был натренирован по тренировочной выборке, содержащей
# 10 объектов класса 0 и 10 объектов класса 1.
#
# Оба классификатора выдают одинаковые ответы (они для любого объекта говорят, что он с
# вероятностью 0.5 принадлежит классу 0 и с вероятностью 0.5 принадлежит классу 1).
# Однако значения функции потерь на тренировочной выборке у них различны (вот это
# поворот!).
#
# Найдите значение функции потерь для каждого классификатора.
#
# Спойлер. Если вы всё сделали правильно, то функция потерь выше у тренировочной
# выборки классификатора К2. Это означает, что К2 "более глуп", чем К1. Дело в том, что К2
# имел в своем распоряжении бОльшую выборку, чем К1, но ничего кроме дурацкой
# стратегии классификации из нее не извлёк. Поэтому и функция потерь у него больше.
#
# $
# L = -(5\cdot\ln(0.5) + 5\cdot\ln(0.5)) = 10\cdot\ln(2) \approx 6.93
# $
#
# $
# L = -(10\cdot\ln(0.5) + 10\cdot\ln(0.5)) = 20\cdot\ln(2) \approx 13.8629
# $

# %% [markdown]
# ##### 5
# Допустим, что наша тренировочная выборка состоит из 4-х объектов. Три объекта А1, А2,
# А3 в реальности принадлежат классу 0, а один объект А4 в реальности принадлежит классу 1.
#
# Как будет работать дурацкий классификатор К1 на такой выборке? Подсчитайте его
# функцию потерь.
#
# А теперь рассмотрим другой (не-дурацкий) классификатор К2. Он для объектов А1, А2, А3
# выдал вероятность принадлежности классу 0 равную 0.6.
# Чему равна вероятность
# принадлежности объекта А4 к классу 1 по мнению классификатора К2, если известно, что
# функция потерь К2 на всей тренировочной выборке численно равна функции потерь
# классификатора К1?
#
# $
# L = -(3\cdot\ln(\frac{3}{4}) + 1\cdot\ln(\frac{1}{4})) =  -3 \cdot \ln\left(\frac{3}{4}\right) + \ln(4)\approx 2.24
# $
#
# Веротность принадлежности объекута А4 к классу 1 у К2 - недурацкого клафссификатора
#
# $
# -\ln(0.6) - \ln(x) = -3 \cdot \ln\left(\frac{3}{4}\right) + \ln(4)
# $
#
# $
# -\ln(x) = \ln\left(\frac{256}{27}\right) + \ln(0.6)
# $
#
# $
# x = \frac{45}{256}
# $
#
# $
# x = \frac{45}{256} \approx 0.17
# $

# %% [markdown]
# ![image.png](8.jpg)
#
# Вычислим предсказания и абсолютные ошибки:
#
# **$x = 1.5$:**
#
# $
# F(1.5) = (0.5)(-0.5)(-1.5)(-2.5) = -0.9375.
# $
#
# Ошибка $|0 - 0.9375| = 0.9375$.
#
# **$x = 2.5$:**
#
# $
# F(2.5) = (1.5)(0.5)(-0.5)(-1.5) = 0.5625.
# $
#
# Ошибка $|0 - 0.5625| = 0.5625$.
#
# **$x = 3.5$:**
#
# $
# F(3.5) = (2.5)(1.5)(0.5)(-0.5) = -0.9375.
# $
#
# Ошибка $|0 - 0.9375| = 0.9375$.
#
# $
# \text{MAE} = \frac{0.9375 + 0.5625 + 0.9375}{3} = 0.8125.
# $

# %% [markdown]
# ![image.png](9.jpg)
#
# 1. $
#    \text{MAE} = \frac{1}{2} \left( |0.25 - a| + |0.25 - a| \right) = |0.25 - a|
#    $
#
#
# 2. Требуется, чтобы $\text{MAE} \leq 0.05$:
#    $
#    |0.25 - a| \leq 0.05
#    $
#
# 3. Решение неравенства
#    $
#    -0.05 \leq 0.25 - a \leq 0.05
#    $
#    $
#    0.25 - 0.05 \leq a \leq 0.25 + 0.05
#    $
#    $
#    a \in [0.20,\, 0.30]
#    $
#
# 4. $
#    a_{\max} = 0.30
#    $

# %% [markdown]
# ![image.png](10.jpg)
#
# Матрица ошибок:
#
# |           | Прогноз 0 | Прогноз 1 |
# |-----------|-----------|-----------|
# | Истина 0 | 90        | 5         |
# | Истина 1 | 2         | 3         |
#
# $
# \text{Precision} = \frac{TP}{TP + FP} = \frac{3}{3 + 5} = 0.375
# $
#
# $
# \text{Recall} = \frac{TP}{TP + FN} = \frac{3}{3 + 2} = 0.6
# $

# %% [markdown]
# ![image.png](11.jpg)
#
# $
# \text{Precision} = \frac{TP}{TP + FP}
# $
#
# $
# 0.4 \times (4 + FP) = 4
# $
#
# $
# 1.6 + 0.4 \times FP = 4
# $
#
# $
# 0.4 \times FP = 4 - 1.6
# $
#
# $
# 0.4 \times FP = 2.4
# $
#
# $
# FP = \frac{2.4}{0.4} = 6
# $

# %% [markdown]
# ![image.png](12.jpg)
#
# $
# \text{F1} = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}} = 2 \times \frac{0.7 \times 0.8}{0.7 + 0.8} = \frac{1.12}{1.5} = 0.746
# $
#
# Если поменять местами Precision и Recall, то F1 не поменяется.

# %% [markdown]
# ![image.png](13.jpg)
#
# $
# F_{\beta} = (1 + \beta^2) \cdot \frac{\text{Precision} \cdot \text{Recall}}{(\beta^2 \cdot \text{Precision}) + \text{Recall}}
# $
#
# 1. β = 2, precision = 0.7, recall = 0.8
#
#     $
#     F_2 = (1 + 2^2) \cdot \frac{0.7 \cdot 0.8}{(2^2 \cdot 0.7) + 0.8} = 5 \cdot \frac{0.56}{2.8 + 0.8} = 0.778
#     $
#
#
# 2. β = 2, precision = 0.8, recall = 0.7
#
#     $
#     F_2 = (1 + 2^2) \cdot \frac{0.8 \cdot 0.7}{(4 \cdot 0.8) + 0.7} = 5 \cdot \frac{0.56}{3.9} = 0.718
#     $
#
#
# 3. β = 0.5, precision = 0.7, recall = 0.8
#
#     $
#     F_{0.5} = (1 + 0.5^2) \cdot \frac{0.7 \cdot 0.8}{(0.5^2 \cdot 0.7) + 0.8} = 1.25 \cdot \frac{0.56}{0.175 + 0.8} = 0.718
#     $
#
# 4. β = 0.5, precision = 0.8, recall = 0.7
#
#     $
#     F_{0.5} = (1 + 0.5^2) \cdot \frac{0.8 \cdot 0.7}{(0.5^2 \cdot 0.8) + 0.7} = 1.25 \cdot \frac{0.56}{0.2 + 0.7} = 0.778
#     $
